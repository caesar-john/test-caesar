# %%
import pandas as pd

# %%
print('Hello world')
# Out:
# Hello world

# %%
print('test vs code gabung ke github')
# Out:
# test vs code gabung ke github

# %%
perkalian = 2 * 2
print(perkalian)
# Out:
# 4

# %%
print('sesi part kode ini telah selesai')
# Out:
# sesi part kode ini telah selesai
